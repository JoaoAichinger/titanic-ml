# %%
import sys
sys.path.append('..')

# %%
import src.data_loader as dl
import src.preprocessor as pr
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = dl.load_data('../data/titanic.csv')
df = pr.preprocess(df)

# %%
target = df['Survived']
features = df.drop(columns=['Survived', 'PassengerId', 'Name', 'Ticket']).copy()
X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.2, random_state=42)

    #Start regression
lr = LogisticRegression()
lr.fit(X_train, Y_train)
Y_pred = lr.predict(X_test)

lr.coef_
# Out:
# array([[-0.53406087,  1.98333749, -0.12075701, -0.03283769,  0.12308262,
#         -0.06280271, -0.05933103, -0.08157088, -0.48025624]])

# %%
df_temp = pd.DataFrame({'features': features.columns, 'coef': lr.coef_[0]})
df_temp
# Out:
#      features      coef
# 0      Pclass -0.534061
# 1         Sex  1.983337
# 2         Age -0.120757
# 3        Fare -0.032838
# 4  Embarked_C  0.123083
# 5  Embarked_Q -0.062803
# 6  Embarked_S -0.059331
# 7  FamilySize -0.081571
# 8     isAlone -0.480256

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.7094972067039106

# %%
df = df.drop(columns=['Fare']).copy() #Didn't alter the result
df = df.drop(columns=['FamilySize']).copy() #Didn't alter the result
df = df.drop(columns=['Embarked_Q']).copy() #Didn't alter the result
df = df.drop(columns=['Embarked_S']).copy() #Didn't alter the result
df = df.drop(columns=['Embarked_C']).copy() #Delete made results more accurate
df = df.drop(columns=['isAlone']).copy() #Didn't alter the result
#df = df.drop(columns=['Sex']).copy() #Delete made accuracy worse
df = df.drop(columns=['Age']).copy() #Didn't alter the result





def train(df):
    target = df['Survived']
    features = df.drop(columns=['Survived', 'PassengerId', 'Name', 'Ticket']).copy()
    X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.2, random_state=42)

        #Start regression
    lr = LogisticRegression()
    lr.fit(X_train, Y_train)
    Y_pred = lr.predict(X_test)
    return accuracy_score(Y_test, Y_pred)

train(df)
# Out:
# 0.7150837988826816
