# %% [markdown]
# #Day 1 - Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('../data/titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         1       1
# 887          888         1       1
# 888          889         0       3
# 889          890         0       3
# 890          891         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          705 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        421 non-null    str
#  11  Embarked     891 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived     Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  891.00000  705.000000  891.000000  891.000000
# mean    446.000000    0.421998    2.30752   28.584397    0.475870    0.363636
# std     257.353842    0.494156    0.83312   13.366407    0.796221    0.734527
# min       1.000000    0.000000    1.00000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.00000   20.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.00000   28.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.00000   38.000000    1.000000    0.000000
# max     891.000000    1.000000    3.00000   67.000000    4.000000    5.000000
#
#              Fare
# count  891.000000
# mean    38.196003
# std     46.863353
# min      5.107900
# 25%     11.968400
# 50%     17.058600
# 75%     36.457800
# max    197.228900

# %% [markdown]
# ##Dataset do far on day 1:
#
# There are missing ages and missing Cabins on the Dataset. PassangerId is not a value directly related to the analysis. It works as an identifier number to find the Passanger in question.
#
# The target is the Column "Survived". It works as a boolean mark, so the statistics involvin it at the cell above are not relevant.

# %% [markdown]
# #Day 2 - Visual Data Analysis

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
plt.legend(['No', 'Yes'])
plt.show()

# %%
sns.histplot(data=df, x='Age', hue='Survived', multiple='fill')
plt.legend(['Yes', 'No'])

# %%
sns.histplot(data=df, x='Pclass', hue='Survived', multiple='fill')
plt.legend(['Yes', 'No'])

# %%
df.corr(numeric_only = True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.041163 -0.037428 -0.025338 -0.005313 -0.006675
# Survived       -0.041163  1.000000 -0.173653 -0.002195  0.054467  0.010131
# Pclass         -0.037428 -0.173653  1.000000 -0.075268  0.026443 -0.006677
# Age            -0.025338 -0.002195 -0.075268  1.000000 -0.031238  0.043241
# SibSp          -0.005313  0.054467  0.026443 -0.031238  1.000000  0.022705
# Parch          -0.006675  0.010131 -0.006677  0.043241  0.022705  1.000000
# Fare            0.012675  0.147355 -0.787205  0.044784 -0.005655 -0.015331
#
#                  Fare
# PassengerId  0.012675
# Survived     0.147355
# Pclass      -0.787205
# Age          0.044784
# SibSp       -0.005655
# Parch       -0.015331
# Fare         1.000000

# %%
df.corr(numeric_only=True)['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.147355
# SibSp          0.054467
# Parch          0.010131
# Age           -0.002195
# PassengerId   -0.041163
# Pclass        -0.173653
# Name: Survived, dtype: float64

# %% [markdown]
# ##Dataset so far on day 2:
#
# "Women and children first" seems to have some relation to survival rates. Althoug, Age by itself didn't show much effect on making the difference as Sex did. The Correlation between Columns and survival rates showed that: The richer they were, the higher their chances.
#
# Maybe missing ages resulted on poor analysis...

# %% [markdown]
# #Day 3 - Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          705 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        421 non-null    str
#  11  Embarked     891 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(186)

# %%
df['Cabin'].isnull().sum()
# Out:
# np.int64(470)

# %%
df = df.drop(columns='Cabin')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         1       1
# 887          888         1       1
# 888          889         0       3
# 889          890         0       3
# 890          891         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
m = df['Age'].median()
df['Age'] = df['Age'].fillna(m)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         1       1
# 887          888         1       1
# 888          889         0       3
# 889          890         0       3
# 890          891         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Dataset so far on day 3
#
# found columns with NaN values and cleaned them. Removed "Cabin", since that information wasn't relevant for this analisys. Filled 'Age' with Median to avoid untrustworthy data. Median is better than Average because it gets a more central value and is not driven by any extremes.

# %% [markdown]
# #Day 4 - Encoding and Normalization

# %%
'''
0 = male
1 = female
'''
df['Sex'] = df['Sex'].replace(['male', 'female'], [0,1]) 
df['Sex'].value_counts()
# Out:
# Sex
# 0    565
# 1    326
# Name: count, dtype: int64

# %%
df = pd.concat([df, pd.get_dummies(df['Embarked'], prefix='Embarked')], axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         1       1
# 887          888         1       1
# 888          889         0       3
# 889          890         0       3
# 890          891         1       2
#
#                                                   Name Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1
# 2                               Heikkinen, Miss. Laina   1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1
# 4                             Allen, Mr. William Henry   0  35.0      0
# ..                                                 ...  ..   ...    ...
# ...

# %%
df = df.drop(columns=['Embarked'])

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='str')

# %%
scaler = StandardScaler()
df['Age'] = scaler.fit_transform(df[['Age']])
df['Fare'] = scaler.fit_transform(df[['Fare']])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         1       1
# 887          888         1       1
# 888          889         0       3
# 889          890         0       3
# 890          891         1       2
#
#                                                   Name Sex       Age  SibSp  \
# 0                              Braund, Mr. Owen Harris   0 -0.543807      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   1  0.802583      1
# 2                               Heikkinen, Miss. Laina   1 -0.207210      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  0.550135      1
# 4                             Allen, Mr. William Henry   0  0.550135      0
# ..                                                 ...  ..       ...    ...
# ...

# %% [markdown]
# ##Dataset so far on day 4
#
# 1- Encoding of 'Sex' Column to make it more comparable. Algorithms cannot perform mathematical operations on text values
#
# 2- One-Hot Encoding for 'Embark' Column - avoids implying ordinal relationship between categories
#
# 3- Normalized 'Age' and 'Fare' to avoid it beeing confused by the machine as One more important than other because of magnitude of values
